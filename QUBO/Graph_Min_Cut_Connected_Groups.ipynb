# %% [markdown]
# 03/28/2022

# %%
# !pip install pyqubo
# !pip install docplex
# !pip install cplex

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import docplex.mp.model as md
from scipy.spatial import Delaunay
import random
from itertools
